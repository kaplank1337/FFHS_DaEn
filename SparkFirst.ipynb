# %%
lines = spark.read.text("hdfs:///user/tirsus/testme.txt")
lines.first()
# Out:
# Row(value='Heute')

# %%
lines.collect()
# Out:
# [Row(value='Heute'),
#  Row(value='ist'),
#  Row(value='ein'),
#  Row(value='schöner'),
#  Row(value='Tag,'),
#  Row(value='ja'),
#  Row(value='ein'),
#  Row(value='schöner'),
#  Row(value='Tag'),
#  Row(value='')]
